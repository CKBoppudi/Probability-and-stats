# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load the data

# %%
data_sachin = pd.read_csv(r"C:\Users\DELL\Desktop\All Scaler\Scaler common core maths\Sachin_ODI.csv")

# %%
data_sachin.head(6)
# Out:
#    runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30   15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75   51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65   40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37   30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13    9      1      0   44.44     2      Pakistan   Sharjah
# 5   112       1  137  107     15      1  104.67     2     Sri Lanka   Sharjah
#
#          Date        Winner Century  Won
# 0  1995-02-16   New Zealand      No   No
# 1  1995-02-18  South Africa      No   No
# 2  1995-02-22         India      No  Yes
# 3  1995-04-05         India      No  Yes
# 4  1995-04-07      Pakistan      No   No
# 5  1995-04-09         India     Yes  Yes

# %% [markdown]
# # Number of rows and columns

# %%
data_sachin.shape
# Out:
# (360, 14)

# %%
# 360 rows and 14 columns.

# %% [markdown]
# # Probability of win.
# # p(win) = No.of elements in event space (winning)/No.of elements in sample space(all matches).

# %%
data_sachin["Won"].value_counts()
# Out:
# Yes    184
# No     176
# Name: Won, dtype: int64

# %%
184/(184+176)
# Out:
# 0.5111111111111111

# %% [markdown]
# # How to compute the above dynamically.

# %%
data_won = data_sachin[data_sachin["Won"] == "Yes"]

# %%
p_win = len(data_won) / len(data_sachin)
p_win
# Out:
# 0.5111111111111111

# %% [markdown]
# # Probability of scoring a century

# %%
data_sachin.head(2)
# Out:
#    runs  NotOut mins  bf  fours  sixes     sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0  86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1  72.54     2  South Africa  Hamilton
#
#          Date        Winner Century Won
# 0  1995-02-16   New Zealand      No  No
# 1  1995-02-18  South Africa      No  No

# %%
data_centuries = data_sachin[data_sachin["Century"] == "Yes"]

# %%
data_centuries
# Out:
#      runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp  \
# 5     112       1  137  107     15      1  104.67     2     Sri Lanka
# 12    127       1  175  138     15      1   92.02     2         Kenya
# 15    137       0  198  137      8      5  100.00     1     Sri Lanka
# 20    100       0    -  111      9      1   90.09     1      Pakistan
# 23    118       0    -  140      8      2   84.28     1      Pakistan
# 27    110       0    -  138      5      1   79.71     1     Sri Lanka
# 41    114       0  157  126     14      0   90.47     1  South Africa
# 47    104       0  121   97      8      1  107.21     2      Zimbabwe
# 55    117       0  188  137     13      2   85.40     2   New Zealand
# 85    100       0  132   89      5      7  112.35     2     Australia
# 91    143       0  187  131      9      5  109.16     2     Australia
# 92    134       0  195  131     12      3  102.29     2     Australia
# ...

# %%
len(data_centuries)
# Out:
# 46

# %%
p_centuries = len(data_centuries) / len(data_sachin)
p_centuries
# Out:
# 0.12777777777777777

# %% [markdown]
# # Probability of winning and centuries.
# # p(win & centuries)
# # p (win intersection century)
# # p(win ^ century)

# %%
data_sachin.head(10)
# Out:
#    runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp  \
# 0    13       0   30   15      3      0   86.66     1   New Zealand
# 1    37       0   75   51      3      1   72.54     2  South Africa
# 2    47       0   65   40      7      0  117.50     2     Australia
# 3    48       0   37   30      9      1  160.00     2    Bangladesh
# 4     4       0   13    9      1      0   44.44     2      Pakistan
# 5   112       1  137  107     15      1  104.67     2     Sri Lanka
# 6    41       0   51   41      5      0  100.00     2     Sri Lanka
# 7    30       0   30   20      5      0  150.00     1   New Zealand
# 8    39       0   79   51      4      0   76.47     2   New Zealand
# 9     7       0   27   11      1      0   63.63     2   New Zealand
#
#        Ground        Date        Winner Century  Won
# 0      Napier  1995-02-16   New Zealand      No   No
# 1    Hamilton  1995-02-18  South Africa      No   No
# 2     Dunedin  1995-02-22         India      No  Yes
# ...

# %%
data_sachin[["Won" , "Century"]].value_counts()
# Out:
# Won  Century
# No   No         160
# Yes  No         154
#      Yes         30
# No   Yes         16
# dtype: int64

# %%
data_wincen = data_sachin[(data_sachin["Won"] == "Yes") & (data_sachin["Century"] == "Yes")]

# %%
len(data_wincen)
# Out:
# 30

# %%
p_wincen = len(data_wincen) / len(data_sachin)

# %%
p_wincen
# Out:
# 0.08333333333333333

# %%
pd.crosstab(index = data_sachin["Century"] , columns  = data_sachin["Won"] , margins = True)
# Out:
# Won       No  Yes  All
# Century
# No       160  154  314
# Yes       16   30   46
# All      176  184  360

# %%
# He made 16 centuries where India lost.
# He made 30 centuries where India won.
